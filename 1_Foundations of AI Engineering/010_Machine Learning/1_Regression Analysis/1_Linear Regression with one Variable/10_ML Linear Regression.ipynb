# %% [markdown]
# # Machine Learning
#
# Machine Learning Cohort: https://github.com/hemansnation/AI-ML-MLOps-GenAI-Live-Summer-Cohort-2024
#
# When to use which ML Algorithm: https://docs.google.com/spreadsheets/d/1QsPoUosmabD_JDQGZ0G8wO31Jiw1qDgj7S9lJ76hruU/edit?gid=0#gid=0

# %%
Machine Learning

4 math pillars of ml

- statistics
- linear algebra
- calculus
- probability

# %%
structured data

- relational databases
- csv
- excel


what facebook did? - neo4j
graph database

himanshu ---friends---- kiraz

# %%
Supervised                             Unsupervised                          Reinforcement
                                       
Regression                             - clusturing                             reward/experience
- Linear Regression                    - dimension reduction                - markov decision process 
                                       - anomaly detection
Classification
- Logistic Regression

# %% [markdown]
# # Linear Regression with one variable

# %%
Linear - arranged in a straight line

Regression - a technique to determine the statistical relationship between 2 or more variables

# %%
  X          Y
area       price
2500       800000
3000       950000
3200       1000000
3600       1200000
4000       1500000
5000

# %%
y = mx + c

800000 = m(2500) + c
950000 = m(3000) + c

m = 3001
c = 4001

# principal equation

y = 3001(x) + 4001

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("homeprices.csv")

df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area')
plt.ylabel('Price')

plt.scatter(df.area, df.price, color= 'red', marker='+')

# %%
x = df[['area']]

x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y = df.price

y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
# m = slope = gradient = 135.78767123

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# c = intercept = 180616.43835616432

# %%
y = (135.78767123) * x + 180616.43835616432

# %%
y = (135.78767123 * 3100) + 180616.43835616432

y
# Out:
# 601558.2191691643

# %%
model.predict([[3100]])
# Out:
# /Users/him/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([601558.21917808])

# %%
y = b0 + b1x1 + e
