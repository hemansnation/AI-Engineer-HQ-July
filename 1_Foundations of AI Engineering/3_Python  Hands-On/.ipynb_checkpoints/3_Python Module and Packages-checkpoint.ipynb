# %% [markdown]
# ## Build In Modules
#
# - os
# - sys
# - statistics
# - math
# - string
# - random

# %%
## os.py

import os

# %%
# help(os)

# %%
os.mkdir('indoreimages')

# %%
os.getcwd()
# Out:
# '/Users/him/Documents/masterdexter/AI-Engineer-HQ-July/1_Foundations of AI Engineering/3_Python  Hands-On'

# %%
os.rmdir('indoreimages/')

# %%
## sys

import sys

# %%
# help(sys)

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
sys.path
# Out:
# ['/Users/him/miniconda3/lib/python312.zip',
#  '/Users/him/miniconda3/lib/python3.12',
#  '/Users/him/miniconda3/lib/python3.12/lib-dynload',
#  '',
#  '/Users/him/miniconda3/lib/python3.12/site-packages']

# %%
sys.version
# Out:
# '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 12:55:12) [Clang 14.0.6 ]'

# %%
## statistics

import statistics

# %%
statistics.mean([1,2,3,4])
# Out:
# 2.5

# %%
from statistics import *

ages = [20,10,4,25,26,88,21,25]

print(mean(ages))
# Out:
# 27.375

# %%
median(ages)
# Out:
# 23.0

# %%
stdev(ages)
# Out:
# 25.723460664759486

# %%
# math

import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %%
print(math.pow(2,3))
# Out:
# 8.0

# %%
from math import pi, sqrt, floor

# %%
print(sqrt(4))
# Out:
# 2.0

# %%
from random import random, randint

# %%
print(random())
# Out:
# 0.4815480519420974

# %%
## build a captcha generator using python

# %%
print(randint())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(randint())
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
print(randint(5,20))
# Out:
# 15

# %%
print(randint(5,20))
# Out:
# 14

# %% [markdown]
# # Object Oriented Programming
#
#
# 7 properties
#
# 1 - class - updated version of structure
#             collection of variables and methods(functions)
#             class is a blueprint
#
# 2 - object - run time or real time entity
#              hashcode (java), id (python), virtual code (cpp)
#
# 3 - abstraction  - showing only important features without showing any background details
#
# - encapsulation - wrapping up of data in a single unit
#
# 4 - inheritance - acquiring properties of one class into another
#                 - resuing the code
#
# 5 - polymorphism - same name multiple functionalities (method overloading and method overriding)
#
# 6 - dynamic memory allocation - run time memory allocation
#
# 7 - message passing - communication between objects

# %%
# c programming

int a;  allocate 2 bytes

struct student{
    int rollno;
    char name[10];
    float per;
}

# %%
struct student s1;  16 bytes
           int a;   2 bytes

# %%
windows xp

windows 7

windows 10

# %%
add()

add(10,20)
