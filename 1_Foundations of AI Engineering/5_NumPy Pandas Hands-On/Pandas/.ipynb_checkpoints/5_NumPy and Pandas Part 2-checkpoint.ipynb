# %% [markdown]
# # Pandas
#
# for data analytics

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/him/miniconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/him/miniconda3/lib/python3.12/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/him/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/him/miniconda3/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/him/miniconda3/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/him/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
df = pd.read_csv("nyc_weather.csv")

df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df[['Temperature']]
# Out:
#     Temperature
# 0            38
# 1            36
# 2            40
# 3            25
# 4            20
# 5            33
# 6            39
# 7            39
# 8            44
# 9            50
# 10           33
# 11           35
# 12           26
# 13           30
# 14           43
# 15           47
# 16           36
# 17           25
# 18           22
# 19           32
# 20           31
# 21           26
# 22           26
# 23           28
# 24           34
# 25           43
# 26           41
# 27           37
# 28           36
# 29           34
# 30           46

# %%
type(df['Temperature'])
# Out:
# pandas.core.series.Series

# %%
df[['Temperature', 'Humidity']]
# Out:
#     Temperature  Humidity
# 0            38        52
# 1            36        46
# 2            40        47
# 3            25        44
# 4            20        41
# 5            33        35
# 6            39        33
# 7            39        64
# 8            44        77
# 9            50        71
# 10           33        37
# 11           35        53
# 12           26        42
# 13           30        47
# 14           43        62
# 15           47        70
# 16           36        66
# 17           25        53
# 18           22        42
# 19           32        49
# 20           31        45
# 21           26        41
# 22           26        78
# 23           28        53
# 24           34        54
# 25           43        56
# 26           41        45
# 27           37        51
# 28           36        50
# 29           34        46
# 30           46        52

# %%
type(df[['Temperature']])
# Out:
# pandas.core.frame.DataFrame

# %%
print(df['Temperature'][0])
# Out:
# 38

# %%
type(df['Temperature'][0])
# Out:
# numpy.int64

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df['Temperature'].max()
# Out:
# np.int64(50)

# %%
print(df['Temperature'].mean())
# Out:
# 34.67741935483871

# %%
df.shape
# Out:
# (31, 11)

# %%
df.size
# Out:
# 341

# %%
df.ndim
# Out:
# 2

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.loc[4]
# Out:
# EST                     1/5/2016
# Temperature                   20
# DewPoint                      -3
# Humidity                      41
# Sea Level PressureIn       30.57
# VisibilityMiles               10
# WindSpeedMPH                 5.0
# PrecipitationIn                0
# CloudCover                     0
# Events                       NaN
# WindDirDegrees               333
# Name: 4, dtype: object

# %% [markdown]
# ## Handling missing values

# %%
df = pd.read_csv('weather_data2.csv')

df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
import numpy as np

np.nan
# Out:
# nan

# %%
NaN = "Not a Number"

# %%
type(df['day'][0])
# Out:
# str

# %%
df.set_index('day', inplace=True)

df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# ### fillna
#
# fill not available

# %%
new_df = df.fillna(0)

new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        0.0    Snow
# 1/6/2017           0.0        7.0       0
# 1/7/2017          32.0        0.0    Rain
# 1/8/2017           0.0        0.0   Sunny
# 1/9/2017           0.0        0.0       0
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df = df.fillna({
    'temperature': 0,
    'windspeed': 0,
    'event': 'No Event',
})

new_df
# Out:
#            temperature  windspeed     event
# day
# 1/1/2017          32.0        6.0      Rain
# 1/4/2017           0.0        9.0     Sunny
# 1/5/2017          28.0        0.0      Snow
# 1/6/2017           0.0        7.0  No Event
# 1/7/2017          32.0        0.0      Rain
# 1/8/2017           0.0        0.0     Sunny
# 1/9/2017           0.0        0.0  No Event
# 1/10/2017         34.0        8.0    Cloudy
# 1/11/2017         40.0       12.0     Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
## drop na


new_df = df.dropna()

new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df = pd.read_csv('weather_datamissing.csv')

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
np.nan
# Out:
# nan

# %%
new_df = df.replace(-99999, value=np.nan)

new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_df = df.replace({
    'temperature': -99999,
    'windspeed': -99999,
    'event': '0',
}, value=np.nan)

new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
0

'0'
